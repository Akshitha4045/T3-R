# %%
import pandas as pd

# %%
df=pd.read_csv("/Rossmann Stores Data.csv")
# Out:
# <ipython-input-2-777fc15b8e4f>:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("/Rossmann Stores Data.csv")

# %%
df
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday
# 0                  0              1
# 1                  0              1
# ...

# %%
# prompt: from the above data in the file give me linear regression graph code between the sales and customers in python and also represent the title in that graph

import matplotlib.pyplot as plt
import seaborn as sns

# Create a scatter plot with regression line
sns.regplot(x='Customers', y='Sales', data=df)

# Set the title of the plot
plt.title('Linear Regression between Sales and Customers')

# Display the plot
plt.show()

# %%
import pandas as pd

# %%
df1=pd.read_csv("/content/store.csv")

# %%
df1
# Out:
#       Store StoreType Assortment  CompetitionDistance  \
# 0         1         c          a               1270.0
# 1         2         a          a                570.0
# 2         3         a          a              14130.0
# 3         4         c          c                620.0
# 4         5         a          a              29910.0
# ...     ...       ...        ...                  ...
# 1110   1111         a          a               1900.0
# 1111   1112         c          c               1880.0
# 1112   1113         a          c               9260.0
# 1113   1114         a          c                870.0
# 1114   1115         d          c               5350.0
#
#       CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                           9.0                    2008.0       0
# 1                          11.0                    2007.0       1
# 2                          12.0                    2006.0       1
# ...

# %%
# prompt: from the data in the file give me linear regression graph code between the promo2sinceweek and promo2sinceyear in python and also represent the title in the graph

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'df1' is your DataFrame
# If not, replace 'df1' with the actual DataFrame variable name

# Create a scatter plot with regression line
sns.regplot(x='Promo2SinceWeek', y='Promo2SinceYear', data=df1)

# Set the title of the plot
plt.title('Linear Regression between Promo2SinceWeek and Promo2SinceYear')

# Display the plot
plt.show()
